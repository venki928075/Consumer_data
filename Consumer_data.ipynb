# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\DELL\Downloads\project tasks_data_mito.csv')

# %%
data.head(2)
# Out:
#         order_id  order_date    customer_name   segment    country   region  \
# 0   AG-2011-2040  01-01-2011  Toby Braunhardt  Consumer    Algeria   Africa
# 1  IN-2011-47883  01-01-2011      Joseph Holt  Consumer  Australia  Oceania
#
#          product_id         category              product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies       Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies  Acme Trimmer, High Speed   120
#
#    quantity  discount   profit  year
# 0         2       0.0  106.140  2011
# 1         3       0.1   36.036  2011

# %%
data['new_quantity'] = data['quantity']*10 ##add new column to data

# %%
data.head(2)
# Out:
#         order_id  order_date    customer_name   segment    country   region  \
# 0   AG-2011-2040  01-01-2011  Toby Braunhardt  Consumer    Algeria   Africa
# 1  IN-2011-47883  01-01-2011      Joseph Holt  Consumer  Australia  Oceania
#
#          product_id         category              product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies       Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies  Acme Trimmer, High Speed   120
#
#    quantity  discount   profit  year  new_quantity
# 0         2       0.0  106.140  2011            20
# 1         3       0.1   36.036  2011            30

# %%
data.insert(10, 'new_sales_1', data.sales*10) ##add column in exact position in data frame

# %%
data.head(2)
# Out:
#         order_id  order_date    customer_name   segment    country   region  \
# 0   AG-2011-2040  01-01-2011  Toby Braunhardt  Consumer    Algeria   Africa
# 1  IN-2011-47883  01-01-2011      Joseph Holt  Consumer  Australia  Oceania
#
#          product_id         category              product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies       Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies  Acme Trimmer, High Speed   120
#
#                       new_sales_1  \
# 0  408408408408408408408408408408
# 1  120120120120120120120120120120
#
#                                            new_sales  quantity  discount  \
# 0  4084084084084084084084084084084084084084084084...         2       0.0
# 1  1201201201201201201201201201201201201201201201...         3       0.1
#
#     profit  year  new_quantity
# 0  106.140  2011            20
# 1   36.036  2011            30

# %%
data.drop('new_sales_1', axis=1) ##delete column from data frame
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...

# %%
data.drop(['new_sales', 'new_sales_1'],axis=1) ##delete column from data frame
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...

# %%
data.sort_values(by='profit').head(2) ##sort values of data based on profit
# Out:
#              order_id  order_date  customer_name    segment        country  \
# 31884  CA-2013-108196  11/26/2013  Cindy Stewart   Consumer  United States
# 29212    TU-2013-9400   9/26/2013  Denise Monton  Corporate         Turkey
#
#       region        product_id    category  \
# 31884   East   TEC-MA-10000418  Technology
# 29212   EMEA  TEC-MOT-10003050  Technology
#
#                                     product_name  sales  \
# 31884  Cubify CubeX 3D Printer Double Head Print  4,500
# 29212             Motorola Smart Phone, Cordless  3,085
#
#                                              new_sales_1  \
# 31884  4,5004,5004,5004,5004,5004,5004,5004,5004,5004...
# 29212  3,0853,0853,0853,0853,0853,0853,0853,0853,0853...
#
#                                                new_sales  quantity  discount  \
# 31884  4,5004,5004,5004,5004,5004,5004,5004,5004,5004...         5       0.7
# 29212  3,0853,0853,0853,0853,0853,0853,0853,0853,0853...        12       0.6
#
# ...

# %%
data[data['region']=='East'].head(2) ##extract data from df where region is East
# Out:
#            order_id  order_date customer_name   segment        country region  \
# 57   CA-2011-141817  01-06-2011    Mick Brown  Consumer  United States   East
# 154  CA-2011-130092  01-12-2011   Seth Vernon  Consumer  United States   East
#
#           product_id         category  \
# 57   OFF-AR-10003478  Office Supplies
# 154  FUR-FU-10000010        Furniture
#
#                                           product_name sales  \
# 57   Avery Hi-Liter EverBold Pen Style Fluorescent ...    20
# 154    DAX Value U-Channel Document Frames, Easel Back    10
#
#               new_sales_1                                          new_sales  \
# 57   20202020202020202020  2020202020202020202020202020202020202020202020...
# 154  10101010101010101010  1010101010101010101010101010101010101010101010...
#
#      quantity  discount  profit  year  new_quantity
# 57          3       0.2  4.8840  2011            30
# 154         2       0.0  3.0814  2011            20

# %%
data[(data['region']=='East') & (data['segment']=='Consumer')].head(2) ##get data from df using AND operator
# Out:
#            order_id  order_date customer_name   segment        country region  \
# 57   CA-2011-141817  01-06-2011    Mick Brown  Consumer  United States   East
# 154  CA-2011-130092  01-12-2011   Seth Vernon  Consumer  United States   East
#
#           product_id         category  \
# 57   OFF-AR-10003478  Office Supplies
# 154  FUR-FU-10000010        Furniture
#
#                                           product_name sales  \
# 57   Avery Hi-Liter EverBold Pen Style Fluorescent ...    20
# 154    DAX Value U-Channel Document Frames, Easel Back    10
#
#               new_sales_1                                          new_sales  \
# 57   20202020202020202020  2020202020202020202020202020202020202020202020...
# 154  10101010101010101010  1010101010101010101010101010101010101010101010...
#
#      quantity  discount  profit  year  new_quantity
# 57          3       0.2  4.8840  2011            30
# 154         2       0.0  3.0814  2011            20

# %%
data[(data['region']=='East') | (data['segment']=='Consumer')].head(2) ##get data from df using OR operator
# Out:
#         order_id  order_date    customer_name   segment    country   region  \
# 0   AG-2011-2040  01-01-2011  Toby Braunhardt  Consumer    Algeria   Africa
# 1  IN-2011-47883  01-01-2011      Joseph Holt  Consumer  Australia  Oceania
#
#          product_id         category              product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies       Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies  Acme Trimmer, High Speed   120
#
#                       new_sales_1  \
# 0  408408408408408408408408408408
# 1  120120120120120120120120120120
#
#                                            new_sales  quantity  discount  \
# 0  4084084084084084084084084084084084084084084084...         2       0.0
# 1  1201201201201201201201201201201201201201201201...         3       0.1
#
#     profit  year  new_quantity
# 0  106.140  2011            20
# 1   36.036  2011            30

# %%
data.pivot_table(index='region', columns='year', values='profit') ##data get using pivot table
# Out:
# year                 2011       2012       2013       2014
# region
# Africa          13.906117  13.502194  20.623734  24.218885
# Canada          29.146452  54.919551  48.391132  47.189055
# Caribbean       15.082730  25.162592  17.560742  23.037897
# Central         26.863066  27.071195  31.877129  26.052672
# Central Asia    63.816888  65.559007  64.792920  64.514896
# EMEA             6.270819   5.074508   8.102479  12.479472
# East            32.997310  32.750020  26.374917  36.003629
# North           45.747739  46.404687  40.512617  34.526721
# North Asia      76.208955  57.301270  78.337498  69.987322
# Oceania         39.318826  37.468841  40.889220  26.346669
# South           15.467160  21.086021  22.012811  23.364694
# Southeast Asia   5.669574   4.199580   3.992691   7.828239
# West            30.356568  31.919306  29.912531  39.945974

# %%
data.pivot_table(index='region', columns='category', values='profit', aggfunc={'profit':'sum'}) ##data get using pivot table
# Out:
# category         Furniture  Office Supplies    Technology
# region
# Africa          16262.0850       28480.0530   44129.49300
# Canada           2613.2400        7957.5300    7246.62000
# Caribbean        6223.4600       14818.2760   13529.58504
# Central         54550.8401      121314.7209  135538.42064
# Central Asia    48935.7120       27104.5000   56439.97500
# EMEA            11534.1360       14869.3920   17494.44300
# East             3046.1658       41014.5791   47462.03510
# North           30922.0680       64403.3930   99272.49152
# North Asia      52181.3010       40926.1050   72471.01500
# Oceania         33626.4340       33306.1860   54734.02200
# South           22651.6281       67495.9988   50208.13928
# Southeast Asia  -7269.7665        4173.2515   20948.84400
# West            11504.9503       52609.8490   44303.64960

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.sales, data.profit)

# %%
data['con'] = data['country']+ ' (' + data['region']+ ' )' ##concatinate two columns to single column

# %%
data
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...
